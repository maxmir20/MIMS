# %%
def palindrome_mega():
    a = 91
    b = 1
    
    
    #print(pal)
    #print(strl.join(pal))
    #paltest(pal)
    while b != 1000:
        #print(b)
        product = str(a * b)
        #print(product)
        strl = ""
        pal = list(product)
        if paltest(pal):
            print(str(a) + " * " + str(b) + "is a palindrome")
        b += 1
        
    
    
def paltest(pal):
    i=1
    #print(pal[i-1] == pal[len(pal)-1]) 
    palintest = False
    
    while pal[i-1] == pal[len(pal)-i]:
        #print(pal[i-1])
        if i == len(pal) - 1 or len(pal) - 2 * i == 1:
            palintest = True
            return palintest
        i+=1
    
    return palintest

def main():
    palindrome_mega()
    return
main()
# Out:
# 91 * 11is a palindrome
# 91 * 22is a palindrome
# 91 * 33is a palindrome
# 91 * 44is a palindrome
# 91 * 55is a palindrome
# 91 * 66is a palindrome
# 91 * 77is a palindrome
# 91 * 88is a palindrome
# 91 * 99is a palindrome
# 91 * 111is a palindrome
# 91 * 121is a palindrome
# 91 * 222is a palindrome
# 91 * 232is a palindrome
# 91 * 242is a palindrome
# 91 * 333is a palindrome
# 91 * 343is a palindrome
# 91 * 353is a palindrome
# 91 * 363is a palindrome
# 91 * 444is a palindrome
# 91 * 454is a palindrome
# 91 * 464is a palindrome
# 91 * 474is a palindrome
# 91 * 484is a palindrome
# 91 * 555is a palindrome
# 91 * 565is a palindrome
# 91 * 575is a palindrome
# 91 * 585is a palindrome
# 91 * 595is a palindrome
# 91 * 605is a palindrome
# 91 * 666is a palindrome
# 91 * 676is a palindrome
# 91 * 686is a palindrome
# 91 * 696is a palindrome
# 91 * 706is a palindrome
# 91 * 716is a palindrome
# 91 * 726is a palindrome
# 91 * 777is a palindrome
# 91 * 787is a palindrome
# ...

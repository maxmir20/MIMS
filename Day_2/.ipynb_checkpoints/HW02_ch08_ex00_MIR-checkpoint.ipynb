# %%
#!/usr/bin/env python3
# HW04_ch08_ex00
# See 8.7

# The following program counts the number of times the letter 'a' appears in a
# string:

#     word = 'banana'
#     count = 0
#     for letter in word:
#         if letter == 'a':
#             count = count + 1
#     print(count)

# Encapsulate this code in a function named "count", and generalize it so that
# it accepts the string and the letter as arguments.

def count(w,l):
    c = 0
    for letter in w:
        if letter == l:
            c += 1
    print(c)

def prompt():
    word = input('please enter a word you would like to use: ')
    letter = input('please enter a letter of that word you would like counted: ')
    count(word, letter)

# Please write a docstring for every function you write.

###############################################################################
# Imports


# Body
#takes a letter inputted 'l', and evaluates it every time the 'for' loop is run
# if the character matches 'l', then it adds a number to the c variable, which is then printed at the end 
def count(w,l):
    c = 0
    for letter in w:
        if letter == l:
            c += 1
    print(c)

#makes a prompt asking for the word and letter the user would like counted, then runs the count function
def prompt():
    word = input('please enter a word you would like to use: ')
    letter = input('please enter a letter of that word you would like counted: ')
    count(word, letter)


###############################################################################
def main():

    # Remove print("Hello World!") and add several functions calls to count()
    # below, passing various strings and letters
    print("Hello World!")

    count('wessley','l')
    
    count('aubergine','e')
    
    count('onomatopoeia','o')

if __name__ == '__main__':
    main()

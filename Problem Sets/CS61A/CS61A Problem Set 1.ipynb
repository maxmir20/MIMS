# %%
from operator import add, sub

def a_plus_abs_b(a, b):
    """Return a+abs(b), but without calling abs.

    >>> a_plus_abs_b(2, 3)
    5
    >>> a_plus_abs_b(2, -3)
    5
    """
    if b < 0:
        f = a + b*(-1)
    else:
        f = a + b
    return f(a, b)

a_plus_abs_b(2, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-da2b410c862f> in <module>
#      15     return f(a, b)
#      16
# ---> 17 a_plus_abs_b(2, 3)
#
# <ipython-input-17-da2b410c862f> in a_plus_abs_b(a, b)
#      13     else:
#      14         f = a + b
# ---> 15     return f(a, b)
#      16
#      17 a_plus_abs_b(2, 3)
#
# TypeError: 'int' object is not callable

# %%
def two_of_three(a, b, c):
    """Return x*x + y*y, where x and y are the two largest members of the
    positive numbers a, b, and c.

    >>> two_of_three(1, 2, 3)
    13
    >>> two_of_three(5, 3, 1)
    34
    >>> two_of_three(10, 2, 8)
    164
    >>> two_of_three(5, 5, 5)
    50
    """
    min(a,b,c)
    return (x^2 + y^2)

# %%
def largest_factor(n):
    """Return the largest factor of n that is smaller than n.

    >>> largest_factor(15) # factors are 1, 3, 5
    5
    >>> largest_factor(80) # factors are 1, 2, 4, 5, 8, 10, 16, 20, 40
    40
    >>> largest_factor(13) # factor is 1 since 13 is prime
    1
    """
    factor_list = []
    i = 1
    while i < n:
        if n%i == 0:
            factor_list.append(i)
        i += 1
    print(factor_list)

largest_factor(12314)
# Out:
# [1, 2, 47, 94, 131, 262, 6157]

# %%
def if_function(condition, true_result, false_result):
    """Return true_result if condition is a true value, and
    false_result otherwise.

    >>> if_function(True, 2, 3)
    2
    >>> if_function(False, 2, 3)
    3
    >>> if_function(3==2, 3+2, 3-2)
    1
    >>> if_function(3>2, 3+2, 3-2)
    5
    """
    if condition:
        return true_result
    else:
        return false_result

# %%
def hailstone(n):
    """Print the hailstone sequence starting at n and return its
    length.

    >>> a = hailstone(10)
    10
    5
    16
    8
    4
    2
    1
    >>> a
    7
    """
    print(n)
    steps = 0
    while n != 1:
        if n%2 == 0:
            n = int(n/2)
        else:
            n= int(n*3 + 1)
        steps +=1
        print(n)

hailstone(27)
# Out:
# 27
# 82
# 41
# 124
# 62
# 31
# 94
# 47
# 142
# 71
# 214
# 107
# 322
# 161
# 484
# 242
# 121
# 364
# 182
# 91
# 274
# 137
# 412
# 206
# 103
# 310
# 155
# 466
# 233
# 700
# 350
# 175
# 526
# 263
# 790
# 395
# 1186
# 593
# 1780
# 890
# 445
# 1336
# 668
# 334
# 167
# 502
# 251
# 754
# 377
# 1132
# 566
# 283
# 850
# 425
# 1276
# 638
# 319
# 958
# 479
# 1438
# 719
# 2158
# 1079
# 3238
# 1619
# 4858
# 2429
# 7288
# 3644
# 1822
# 911
# 2734
# 1367
# 4102
# 2051
# 6154
# 3077
# 9232
# 4616
# 2308
# 1154
# 577
# 1732
# 866
# 433
# 1300
# 650
# 325
# 976
# 488
# 244
# 122
# 61
# 184
# 92
# 46
# 23
# 70
# 35
# 106
# 53
# 160
# 80
# 40
# 20
# 10
# 5
# 16
# 8
# 4
# 2
# 1

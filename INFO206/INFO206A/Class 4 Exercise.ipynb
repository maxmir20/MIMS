# %%
import drawSvg as draw
color='blue'
next_color = 'red'
temp = ''
d = draw.Drawing(200,200, origin='center')

#d.append(draw.Rectangle(-90 + 80,-100 + 0,20,20, fill=color))



for i in range(0,9):
    for j in range(0,9):
        d.append(draw.Rectangle(-90 + j*10,-100 + i*10,10,10, fill=color))
        temp = color
        color = next_color
        next_color = temp        
        
d
